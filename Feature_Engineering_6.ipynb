# %% [markdown]
# Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose
# you have collected data on the amount of time students spend studying for an exam and their final exam
# scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.
#
# Answer :

# %%
import pandas as pd
df = pd.DataFrame({"study_time":[8,5,6,9,4,7,2,3],
                   "exam_score":[85,70,75,90,60,80,50,65]})
df.corr(method = "pearson")
# Out:
#             study_time  exam_score
# study_time    1.000000    0.972286
# exam_score    0.972286    1.000000

# %% [markdown]
# Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables.
# Suppose you have collected data on the amount of sleep individuals get each night and their overall job
# satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two
# variables and interpret the result.
#
# Answer:

# %%
import pandas as pd
import numpy as np
# creating a sample data of 10 individuals
sleep_hours = [np.random.randint(4,9) for i in range(10)]
rating = [np.random.randint(1,11) for i in range(10)]
df = pd.DataFrame({'sleep_hours':sleep_hours,'job_satisfaction_level':rating})

# %%
df.corr(method = "spearman")
# Out:
#                         sleep_hours  job_satisfaction_level
# sleep_hours                  1.0000                  0.1625
# job_satisfaction_level       0.1625                  1.0000

# %% [markdown]
# Q3. Suppose you are conducting a study to examine the relationship between the number of hours of
# exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables
# for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation
# between these two variables and compare the results.
#
# Answer:

# %%
import pandas as pd
import numpy as np
# creating a sample data of 50 participants
exercise_per_week  = [np.random.randint(0,6) for i in range(50)]
BMI = [np.random.randint(10,25 ) for i in range(50)]
df = pd.DataFrame({'exercise_per_week':exercise_per_week,'BMI':BMI})

# %%
df.corr(method = "pearson")
# Out:
#                    exercise_per_week       BMI
# exercise_per_week           1.000000 -0.021388
# BMI                        -0.021388  1.000000

# %%
df.corr(method = "spearman")
# Out:
#                    exercise_per_week       BMI
# exercise_per_week           1.000000 -0.019231
# BMI                        -0.019231  1.000000

# %% [markdown]
# **Comparing the resultt**

# %%
import seaborn as sns
sns.lineplot(x='exercise_per_week',y='BMI',data=df)
# Out:
# <Axes: xlabel='exercise_per_week', ylabel='BMI'>

# %% [markdown]
# Q4. A researcher is interested in examining the relationship between the number of hours individuals
# spend watching television per day and their level of physical activity. The researcher collected data on
# both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between
# these two variables.
#
# Answer:

# %%
import pandas as pd
df =pd.DataFrame({
    "spending_time ": [np.random.randint(0,11) for i in range(50)],
    "physical_activity":[np.random.randint(0,11) for i in range(50)]
})

# %%
df.corr(method="pearson")
# Out:
#                    spending_time   physical_activity
# spending_time            1.000000           0.121668
# physical_activity        0.121668           1.000000

# %% [markdown]
# Q5. A survey was conducted to examine the relationship between age and preference for a particular
# brand of soft drink. The survey results are shown below:
#
# Answer:

# %%
import pandas as pd
df = pd.DataFrame({'Age(Years)':[25,42,37,19,31,28],'Soft drink Preference': ['Coke' ,'Pepsi', 'Mountain Dew', 'Coke', 'Pepsi', 'Coke']})
df
# Out:
#    Age(Years) Soft drink Preference
# 0          25                  Coke
# 1          42                 Pepsi
# 2          37          Mountain Dew
# 3          19                  Coke
# 4          31                 Pepsi
# 5          28                  Coke

# %%
import seaborn as sns
sns.countplot(x='Soft drink Preference',hue='Age(Years)',data=df)
# Out:
# <Axes: xlabel='Soft drink Preference', ylabel='count'>

# %% [markdown]
# Interpreting the result
#
# The resulting plot will show the number of people in each age group who prefer each brand of soft drink.
#
# Based on the survey results, there were 6 participants in total, with ages ranging from 19 to 42. Among the 6 participants, the most popular soft drink preference was Coke, which was preferred by 3 participants, followed by Pepsi, which was preferred by 2 participants, and Mountain Dew, which was preferred by 1 participant.
#
# Looking at the relationship between age and soft drink preference, we can see that among the participants who preferred Coke, one was aged 19, second was aged 25 and third was aged 28. Among the participants who preferred Pepsi, one was aged 31 and the other was aged 42. The participant who preferred Mountain Dew was aged 37.

# %% [markdown]
# Q6. A company is interested in examining the relationship between the number of sales calls made per day
# and the number of sales made per week. The company collected data on both variables from a sample of
# 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.
#
# Answer:

# %%
import pandas as pd
df =pd.DataFrame({
    "no_of_calls_per_day ": [np.random.randint(20,51) for i in range(50)],
    "no_of_seles_per_week":[np.random.randint(50,100) for i in range(50)]
})

# %%
df.corr(method="pearson")
# Out:
#                       no_of_calls_per_day   no_of_seles_per_week
# no_of_calls_per_day               1.000000             -0.026007
# no_of_seles_per_week             -0.026007              1.000000
